# %%
import pandas as pd

# %%
df1 = pd.read_csv('Q1Responses.csv')

# %%
df2 = pd.read_csv('Q2Responses.csv')

# %%
df3 = pd.read_csv('Q3Responses.csv')

# %%
df4 = pd.read_csv('Q4Responses.csv')

# %%
df5 = pd.read_csv('Q5Responses.csv')

# %%
df6 = pd.read_csv('Q6Responses.csv')

# %%
df7 = pd.read_csv('Q7Responses.csv')

# %%
df = pd.merge(df1,df2,on='StudentID')

# %%
df = pd.merge(df,df7,on = 'StudentID')

# %%
df.head()
# Out:
#    StudentID  Q1  Q2  Q3  Q4  Q5  Q6  Q7
# 0      10165   2   2   3   2   2   2   3
# 1      10281   2   2   3   2   2   2   3
# 2      11574   3   2   2   2   3   3   2
# 3      12296   2   2   0   0   2   2   1
# 4      12434   0   0   1   0   1   1   2

# %%
df.sort_values(by=['StudentID'], inplace=True)

# %%
df.head()
# Out:
#    StudentID  Q1  Q2  Q3  Q4  Q5  Q6  Q7
# 0      10165   2   2   3   2   2   2   3
# 1      10281   2   2   3   2   2   2   3
# 2      11574   3   2   2   2   3   3   2
# 3      12296   2   2   0   0   2   2   1
# 4      12434   0   0   1   0   1   1   2

# %%
df.to_csv('HADS.csv')

# %%
df = pd.read_csv('HADS.csv')

# %%
df.head()
# Out:
#    StudentID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Sum      Result
# 0      10165   2   2   3   2   2   2   3   16    Abnormal
# 1      10281   2   2   3   2   2   2   3   16    Abnormal
# 2      11574   3   2   2   2   3   3   2   17    Abnormal
# 3      12296   2   2   0   0   2   2   1    9  Borderline
# 4      12434   0   0   1   0   1   1   2    5      Normal

# %%
df.dtypes
# Out:
# StudentID    int64
# Q1           int64
# Q2           int64
# Q3           int64
# Q4           int64
# Q5           int64
# Q6           int64
# Q7           int64
# Sum          int64
# dtype: object

# %%
# for i in range(0,len(df)):
#     if df[df['Sum']>=0 and df[df['Sum']<=7]:
#         df["Result"] = 'Normal'
#     elif df[df['Sum']>=8 and df[df['Sum']<=10]:
#         df["Result"] = 'Borderline'
#     elif df[df['Sum']>=11 and [df['Sum']<=21]:
#         df["Result"] = 'Abnormal'

# %%
df = pd.read_csv('StudentFactorsUnique.csv')

# %%
df
# Out:
#        Unnamed: 0  StudentID Gender  Height  Weight   Age Peer Pressure  \
# 0               0    10165.0      M     4.9    42.0  27.0             Y
# 1               1    10281.0      M     5.6    69.0  27.0             Y
# 2               2    11574.0      M     5.3    40.0  18.0             N
# 3               3    12296.0      F     4.5    71.0  25.0             N
# 4               4    12434.0      F     5.5    80.0  13.0             N
# 5               5    13400.0      M     5.4    55.0  20.0             Y
# 6               6    13965.0      F     5.0    47.0  27.0             Y
# 7               7    14287.0      M     4.7    61.0  28.0             N
# 8               8    16677.0      M     4.9    69.0  18.0             Y
# 9               9    16796.0      M     5.2    74.0  13.0             N
# 10             10    17138.0      M     4.5    64.0  27.0             Y
# 11             11    18161.0      F     5.2    74.0  28.0             N
# ...

# %%
df1 = pd.read_csv('HADS.csv')

# %%
# df1.head()
# df.isnull().sum()
df


# df1.isnull().sum()
# Out:
#        Unnamed: 0  StudentID Gender  Height  Weight   Age Peer Pressure  \
# 0               0    10165.0      M     4.9    42.0  27.0             Y
# 1               1    10281.0      M     5.6    69.0  27.0             Y
# 2               2    11574.0      M     5.3    40.0  18.0             N
# 3               3    12296.0      F     4.5    71.0  25.0             N
# 4               4    12434.0      F     5.5    80.0  13.0             N
# 5               5    13400.0      M     5.4    55.0  20.0             Y
# 6               6    13965.0      F     5.0    47.0  27.0             Y
# 7               7    14287.0      M     4.7    61.0  28.0             N
# 8               8    16677.0      M     4.9    69.0  18.0             Y
# 9               9    16796.0      M     5.2    74.0  13.0             N
# 10             10    17138.0      M     4.5    64.0  27.0             Y
# 11             11    18161.0      F     5.2    74.0  28.0             N
# ...

# %%
df1.drop_duplicates(subset ="StudentID", 
                     keep = False, inplace = True)

# %%
df_final = pd.merge(df,df1,on='StudentID')

# %%
df_final.to_csv('Final2.csv')

# %%
#  df_final.isnull().sum()

# %%
# bo = pd.isnull(df_final['Age'])

# %%
# df_final[bo]

# %%
df_final
# Out:
#        StudentID Gender  Height  Weight   Age Peer Pressure  \
# 0          10165      M     4.9    42.0  27.0             Y
# 1          10281      M     5.6    69.0  27.0             Y
# 2          11574      M     5.3    40.0  18.0             N
# 3          12296      F     4.5    71.0  25.0             N
# 4          12434      F     5.5    80.0  13.0             N
# 5          13400      M     5.4    55.0  20.0             Y
# 6          13965      F     5.0    47.0  27.0             Y
# 7          14287      M     4.7    61.0  28.0             N
# 8          16677      M     4.9    69.0  18.0             Y
# 9          16796      M     5.2    74.0  13.0             N
# 10         17138      M     4.5    64.0  27.0             Y
# 11         18161      F     5.2    74.0  28.0             N
# 12         19711      F     5.2    78.0  23.0             N
# 13         20464      M     5.5    64.0  26.0             Y
# 14         20687      M     4.6    68.0  19.0             Y
# ...
