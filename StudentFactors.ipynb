# %%
import pandas as pd

# %%
df1 = pd.read_csv('GeneralCharacterstics.csv')

# %%
df1.head()
# Out:
#    StudentID Gender  Height  Weight   Age
# 0  3144076.0      M     5.0    62.0  21.0
# 1  8046964.0      M     4.5    69.0  18.0
# 2  7843714.0      M     5.2    68.0  20.0
# 3  4036017.0      M     6.2    49.0  19.0
# 4  6141936.0      M     4.8    45.0  18.0

# %%
df2 = pd.read_csv('OtherFactors.csv')

# %%
df2.head()
# Out:
#   Peer Pressure Living with Family Past History Smoke  StudentID
# 0             Y                  N            Y     Y  3144076.0
# 1             Y                  N            Y     Y  8046964.0
# 2             Y                  Y            Y     Y  7843714.0
# 3             Y                  Y            Y     Y  4036017.0
# 4             N                  Y            Y     Y  6141936.0

# %%
df_merge = pd.merge(df1, df2, on='StudentID')

# %%
df_merge.head()
# Out:
#    StudentID Gender  Height  Weight   Age Peer Pressure Living with Family  \
# 0  3144076.0      M     5.0    62.0  21.0             Y                  N
# 1  8046964.0      M     4.5    69.0  18.0             Y                  N
# 2  7843714.0      M     5.2    68.0  20.0             Y                  Y
# 3  4036017.0      M     6.2    49.0  19.0             Y                  Y
# 4  6141936.0      M     4.8    45.0  18.0             N                  Y
#
#   Past History Smoke
# 0            Y     Y
# 1            Y     Y
# 2            Y     Y
# 3            Y     Y
# 4            Y     Y

# %%
df3 = pd.read_csv('CurrentEducation&IQ.csv')

# %%
df3.head()
# Out:
#    StudentID  IQScore Current Education
# 0  3144076.0     90.0                 G
# 1  8046964.0     96.0                 G
# 2  7843714.0    112.0                 G
# 3  4036017.0     98.0                 G
# 4  6141936.0     99.0                 G

# %%
df1_merge = pd.merge(df_merge,df3,on="StudentID")

# %%
df1_merge.head()
# Out:
#    StudentID Gender  Height  Weight   Age Peer Pressure Living with Family  \
# 0  3144076.0      M     5.0    62.0  21.0             Y                  N
# 1  8046964.0      M     4.5    69.0  18.0             Y                  N
# 2  7843714.0      M     5.2    68.0  20.0             Y                  Y
# 3  4036017.0      M     6.2    49.0  19.0             Y                  Y
# 4  6141936.0      M     4.8    45.0  18.0             N                  Y
#
#   Past History Smoke  IQScore Current Education
# 0            Y     Y     90.0                 G
# 1            Y     Y     96.0                 G
# 2            Y     Y    112.0                 G
# 3            Y     Y     98.0                 G
# 4            Y     Y     99.0                 G

# %%
df1_merge.sort_values(by=['StudentID'], inplace=True)

# %%
# df1_merge

# %%
df1_merge['StudentID'].isnull().sum()
# Out:
# 100

# %%
df4 = pd.read_csv('ExerciseFactor.csv')

# %%
df4.head()
# Out:
#    StudentID Exercise
# 0      10165     None
# 1      10281     None
# 2      11574     None
# 3      12296     None
# 4      12434    Heavy

# %%
df_final = pd.merge(df1_merge,df4,on='StudentID')

# %%
df_final.head()
# Out:
#    StudentID Gender  Height  Weight   Age Peer Pressure Living with Family  \
# 0    10165.0      M     4.9    42.0  27.0             Y                  N
# 1    10281.0      M     5.6    69.0  27.0             Y                  N
# 2    11574.0      M     5.3    40.0  18.0             N                  Y
# 3    12296.0      F     4.5    71.0  25.0             N                  N
# 4    12434.0      F     5.5    80.0  13.0             N                  Y
#
#   Past History Smoke  IQScore Current Education Exercise
# 0            Y     Y     90.0                PG     None
# 1            Y     Y     93.0                PG     None
# 2            Y     Y     99.0                 G     None
# 3            N     Y     96.0                PG     None
# 4            Y     N     89.0                 S    Heavy

# %%
df_final.to_csv('StudentFactors.csv')

# %%
df_final.head()
# Out:
#    StudentID Gender  Height  Weight   Age Peer Pressure Living with Family  \
# 0    10165.0      M     4.9    42.0  27.0             Y                  N
# 1    10281.0      M     5.6    69.0  27.0             Y                  N
# 2    11574.0      M     5.3    40.0  18.0             N                  Y
# 3    12296.0      F     4.5    71.0  25.0             N                  N
# 4    12434.0      F     5.5    80.0  13.0             N                  Y
#
#   Past History Smoke  IQScore Current Education Exercise
# 0            Y     Y     90.0                PG     None
# 1            Y     Y     93.0                PG     None
# 2            Y     Y     99.0                 G     None
# 3            N     Y     96.0                PG     None
# 4            Y     N     89.0                 S    Heavy

# %%
# df2.head()

# %%
# df2.join(df_final,on='StudentID',how='inner',lsuffix='_left', rsuffix='_right')

# %%
# df_final()

# %%
df_final.drop_duplicates(subset ="StudentID", 
                     keep = False, inplace = True)

# %%
df_final.to_csv("StudentFactorsUnique.csv")
